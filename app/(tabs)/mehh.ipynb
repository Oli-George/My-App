# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import classification_report, confusion_matrix

# %%
matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(matrix)

#Printing a confusion matrix in Machine Learning is a way to evaluate the performance of a classification model. It shows the number of true positives, true negatives, false positives, and false negatives. This helps to understand how well the model is performing in terms of correctly classifying the data.
