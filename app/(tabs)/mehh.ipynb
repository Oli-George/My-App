# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from math import randint
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# Was just testing out code cells here. Markdown cells too.

# %%
x = np.linspace(0,10,100)
y = 2*x+1 + np.random.normal(0,1,100)
plt.figure(figsize=(8,8))
plt.style.use('ggplot')
plt.scatter(x, y)
plt.show()

# %%
y_true = [i for i in range(10)]
y_pred = [randint(0,9) for i in range(10)]
confusion_matrix(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 y_true = [i for i in range(10)]
# ----> 2 y_pred = [randint(0,9) for i in range(10)]
#       3 confusion_matrix(y_true, y_pred)
#
# NameError: name 'randint' is not defined
